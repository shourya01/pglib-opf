# %%
import os, pickle
import numpy as np
import torch.nn.functional as F
from oct2py import Oct2Py
import cyipopt
import warnings
from tqdm import trange
from pypower.ext2int import ext2int
from pypower.api import loadcase
from problemDefJITM import opfSocp
from problemDefJITMargin import opfSocpMargin
from utils import make_data_parallel
from tqdm import tqdm, trange
import torch
import torch.nn as nn
import gc
from time import time
from ConvexModel import ConvexNet
from ClassifierModel import ClassifierNet
from RidgeModel import RidgeNet
import xgboost as xgb

from sklearn.tree import DecisionTreeClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.linear_model import RidgeClassifier

octave = Oct2Py()
dir_name = 'data/'
MAX_BUS = 10000
NUM_SOLVES = 20

if __name__ == "__main__":
    
    # get all cases in current directory
    current_directory = os.getcwd()+'/'
    # current_directory = '/home/sbose/pglib-opf/' # for running on BEBOP
    all_files_and_directories = os.listdir(current_directory)
    # three specific cases
    case_files = [current_directory+i for i in ['pglib_opf_case118_ieee.m','pglib_opf_case2312_goc.m',"pglib_opf_case4601_goc.m","pglib_opf_case10000_goc.m"]]
    # case_files = [current_directory+i for i in ['pglib_opf_case2312_goc.m',"pglib_opf_case4601_goc.m"]]

    cases, casenames = [], []
    cases_full, casenames_full = [], []
    
    for cf in case_files:
        octave.source(current_directory+os.path.basename(cf))
        cname = os.path.basename(cf).split('.')[0]
        num_buses = None
        # determine number of buses in the case from its name
        for ci in cname.split('_'):
            if 'case' in ci:
                num_buses = int(''.join([chr for chr in ci.replace('case','',1) if chr.isdigit()]))
        # fitler out cases with more buses than MAX_BUS
        if num_buses <= MAX_BUS:
            # convert to internal indexing
            case_correct_idx = ext2int(loadcase(octave.feval(cname)))
            # append
            cases.append(case_correct_idx)
            casenames.append(cname)
            
    for cn,this_case in zip(casenames,cases):
    
        inp_data = np.load(os.getcwd()+'/'+dir_name+f'{cn}_inp.npz')['data']
        # dual_data = np.load(os.getcwd()+'/'+dir_name+f'{cn}_dual.npz')['data']
        # cost_data = np.load(os.getcwd()+'/'+dir_name+f'{cn}_costs.npz')['data'][:,None]
        
        # # modify the input
        # optObj = opfSocp(this_case,cn) # generate object

        # # import data
        # inp_data = np.load(os.getcwd()+f'/saved/{cn}_test_inp.npz')['data']
        
        # solve for convex
        convex_out = np.load(os.getcwd()+f'/saved/{cn}_out_convex.npz')['data']
        
        times, solves = [], []
        optObj = opfSocp(this_case,cn)
        cub, clb = optObj.calc_cons_bounds()
        xub, xlb = optObj.calc_var_bounds()
        
        # Define IPOPT problem
        prob = cyipopt.Problem(
            n = optObj.in_size,
            m = optObj.cons_size,
            problem_obj=optObj,
            lb=xlb,
            ub=xub,
            cl=clb,
            cu=cub
        )
        
        # Setup solver options
        prob.add_option('tol',1e-6)
        prob.add_option('mumps_mem_percent',25000)
        prob.add_option('mu_max',1e-1) 
        prob.add_option('mu_init',1e-1)
        prob.add_option('max_iter',1000)
        prob.add_option('nlp_lower_bound_inf',-optObj.LARGE_NUMBER+1)
        prob.add_option('nlp_upper_bound_inf',optObj.LARGE_NUMBER-1)
        prob.add_option('print_level',0) 
        
        x,info_base = prob.solve(optObj.calc_x0_flatstart())
        
        for sidx in range(NUM_SOLVES):
            
            pd,qd = inp_data[sidx,:optObj.n_bus], inp_data[sidx,optObj.n_bus:2*(optObj.n_bus)]
            # print(f"pd: {pd}, qd: {qd}")
            
            # time and solve original problem
            optObj.change_loads(pd,qd)
            
            # time variable for original
            time_orig = 0.
            
            # Define IPOPT problem
            prob = cyipopt.Problem(
                n = optObj.in_size,
                m = optObj.cons_size,
                problem_obj=optObj,
                lb=xlb,
                ub=xub,
                cl=clb,
                cu=cub
            )
            
            # Setup solver options
            prob.add_option('tol',1e-6)
            prob.add_option('mumps_mem_percent',25000)
            prob.add_option('mu_max',1e-1) 
            prob.add_option('mu_init',1e-1)
            # prob.add_option('max_iter',1000)
            # prob.add_option('nlp_lower_bound_inf',-optObj.LARGE_NUMBER+1)
            # prob.add_option('nlp_upper_bound_inf',optObj.LARGE_NUMBER-1)
            prob.add_option('print_level',0) 
            
            start = time()
            _, info = prob.solve(info_base['x'],lagrange=info_base['mult_g'].tolist(),zl=info_base['mult_x_L'].tolist(),zu=info_base['mult_x_U'].tolist())
            end = time()
            
            if info['status'] != 0:
                snum = info['status']
                smsg = info['status_msg']
                print(f'For case {cn}, init solve was infeasible with info {smsg} and number {snum}. CONTINUING.')
                continue
            else:
                snum = info['status']
                smsg = info['status_msg']
                print(f'For case {cn}, init solve was feasible with info {smsg} and number {snum}. NOT CONTINUING.')
            
            orig = end-start
            val = info['obj_val']
            print(f'Solved original problem for {cn} in {orig}s, objective value is {val}.')
            
            # solve modified prob - set up indices
            ineqidx = ((1-optObj.is_model)*(1-optObj.is_equality)).astype(bool) # nonmodel inequalities
            nmineq = np.ones(2*optObj.n_bus+4*optObj.n_branch)
            nmineq[:2*optObj.n_bus] = 0
            nmineq = nmineq.astype(bool)
            
            
            this_time, this_solve = 0,0
            marker = convex_out[sidx,:]
            clnew, cunew = clb,cub
            clnew[ineqidx] = np.where(marker[nmineq]==0,-optObj.LARGE_NUMBER,clb[ineqidx])
            cunew[ineqidx] = np.where(marker[nmineq]==0,optObj.LARGE_NUMBER,cub[ineqidx])
            prob = cyipopt.Problem(
                n = optObj.in_size,
                m = optObj.cons_size,
                problem_obj=optObj,
                lb=xlb,
                ub=xub,
                cl=clnew,
                cu=cunew
            )
            # Setup solver options
            prob.add_option('tol',1e-6)
            # prob.add_option('max_iter',2500)
            prob.add_option('mumps_mem_percent',25000)
            prob.add_option('mu_max',1e-0)
            prob.add_option('mu_init',1e-0)
            prob.add_option('nlp_lower_bound_inf',-optObj.LARGE_NUMBER+1)
            prob.add_option('nlp_upper_bound_inf',optObj.LARGE_NUMBER-1)
            prob.add_option('print_level',0) 
            start = time()
            x, info = prob.solve(info_base['x'],lagrange=info_base['mult_g'].tolist(),zl=info_base['mult_x_L'].tolist(),zu=info_base['mult_x_U'].tolist())
            end = time()
            this_time += end-start
            this_solve += 1
            # infer constraints
            inferred_cons = (optObj.constraints(x)-cub).clip(min=0)[ineqidx]
            val = info['obj_val']
            print(f'First solve objective is {val}, {np.where(np.abs(inferred_cons)>1e-3,1,0).sum()} violated cons.')
            if np.where(np.abs(inferred_cons)>1e-4,1,0).sum() > 0:
                marker[nmineq] = np.where(np.abs(inferred_cons)>1e-4,0,inferred_cons)
                # resolve
                clnew, cunew = clb,cub
                clnew[ineqidx] = np.where(marker[nmineq]==0,-optObj.LARGE_NUMBER,clb[ineqidx])
                cunew[ineqidx] = np.where(marker[nmineq]==0,optObj.LARGE_NUMBER,cub[ineqidx])
                prob = cyipopt.Problem(
                    n = optObj.in_size,
                    m = optObj.cons_size,
                    problem_obj=optObj,
                    lb=xlb,
                    ub=xub,
                    cl=clnew,
                    cu=cunew
                )
                # Setup solver options
                prob.add_option('tol',1e-6)
                # prob.add_option('max_iter',2500)
                prob.add_option('mumps_mem_percent',25000)
                prob.add_option('mu_max',1e-0)
                prob.add_option('mu_init',1e-0)
                prob.add_option('nlp_lower_bound_inf',-optObj.LARGE_NUMBER+1)
                prob.add_option('nlp_upper_bound_inf',optObj.LARGE_NUMBER-1)
                prob.add_option('print_level',0) 
                start = time()
                x, info = prob.solve(info_base['x'],lagrange=info_base['mult_g'].tolist(),zl=info_base['mult_x_L'].tolist(),zu=info_base['mult_x_U'].tolist())
                end = time()
                inferred_cons = (optObj.constraints(x)-cub).clip(min=0)[ineqidx]
                val = info['obj_val']
                print(f'Second solve objective is {val}, {np.where(np.abs(inferred_cons)>1e-4,1,0).sum()} violated cons.')
                this_time += end-start
                this_solve += 1
            print(f'For method convex, solved {cn}-reduced in {this_time} with {this_solve} solve(s).\n')
# Out:
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.24505233764648438s, objective value is 83976.23234926627.
# First solve objective is 83976.23264920751, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17014312744140625 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.30803728103637695s, objective value is 84657.93318548545.
# First solve objective is 84657.93349451268, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16805362701416016 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2184736728668213s, objective value is 85069.73204282277.
# First solve objective is 85069.73234647534, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.1729109287261963 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2873504161834717s, objective value is 84515.99011092744.
# First solve objective is 84515.99041367746, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17264485359191895 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2047901153564453s, objective value is 85806.28091288698.
# First solve objective is 85806.28121738034, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16298460960388184 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.20316600799560547s, objective value is 85449.32905391633.
# First solve objective is 85449.32936501874, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16849160194396973 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2508423328399658s, objective value is 86161.40178898712.
# First solve objective is 86161.4020960753, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16313624382019043 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2894613742828369s, objective value is 84936.58645944027.
# First solve objective is 84936.58675792576, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16424822807312012 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.27695298194885254s, objective value is 86272.1482614602.
# First solve objective is 86272.148569061, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16957521438598633 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.28415369987487793s, objective value is 83955.46080187013.
# First solve objective is 83955.46110121103, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17580819129943848 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2528526782989502s, objective value is 85545.8100217968.
# First solve objective is 85545.81032626181, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17393231391906738 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.24510908126831055s, objective value is 85288.10239064075.
# First solve objective is 85288.10267453112, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.164778470993042 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.20280122756958008s, objective value is 84492.17516332568.
# First solve objective is 84492.17546411524, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16419696807861328 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.2301788330078125s, objective value is 82553.30046286127.
# First solve objective is 82553.30075007786, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16922783851623535 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.23566794395446777s, objective value is 84976.7787480302.
# First solve objective is 84976.77905231534, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.16993975639343262 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.20830464363098145s, objective value is 83911.29206090161.
# First solve objective is 83911.29237202929, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17035365104675293 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.28181910514831543s, objective value is 85949.44888061662.
# First solve objective is 85949.44918405994, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.1661689281463623 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.24022293090820312s, objective value is 84703.12329202873.
# First solve objective is 84703.12358283972, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17098093032836914 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.22221732139587402s, objective value is 84525.39526593938.
# First solve objective is 84525.39557167931, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.17080307006835938 with 1 solve(s).
#
# For case pglib_opf_case118_ieee, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case118_ieee in 0.21836447715759277s, objective value is 83884.57085141752.
# First solve objective is 83884.57115399955, 0 violated cons.
# For method convex, solved pglib_opf_case118_ieee-reduced in 0.1733555793762207 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.076175212860107s, objective value is 427488.03093101655.
# First solve objective is 427488.0407874818, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.4658043384552 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 12.688542604446411s, objective value is 427326.77449267294.
# First solve objective is 427326.7843568949, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.771337985992432 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 9.217665195465088s, objective value is 427093.27228938206.
# First solve objective is 427093.2821559701, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.04670786857605 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 11.955009937286377s, objective value is 427577.4501057174.
# First solve objective is 427577.45999136585, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.798043966293335 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 11.030060768127441s, objective value is 427043.93624133867.
# First solve objective is 427043.9460691099, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.620092630386353 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.766501903533936s, objective value is 427075.9782966719.
# First solve objective is 427075.9881475903, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.904865026473999 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 11.117487907409668s, objective value is 426629.0133643291.
# First solve objective is 426629.02320754575, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.555676460266113 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 11.048019647598267s, objective value is 426768.0068934486.
# First solve objective is 426768.01676130836, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 13.522448062896729 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 9.596108675003052s, objective value is 426853.0480978294.
# First solve objective is 426853.05796820886, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.605061769485474 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.093914985656738s, objective value is 426965.7240572714.
# First solve objective is 426965.73393538164, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.742487668991089 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.993033409118652s, objective value is 427313.6906285458.
# First solve objective is 427313.70047026576, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.33857274055481 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.480712652206421s, objective value is 427611.7240008789.
# First solve objective is 427611.733848179, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.254724264144897 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.308377742767334s, objective value is 426488.32449900394.
# First solve objective is 426488.3343559195, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.816236019134521 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.056182384490967s, objective value is 427018.7490562792.
# First solve objective is 427018.75890872045, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.823503494262695 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 9.61630630493164s, objective value is 427413.8099762005.
# First solve objective is 427413.8198449308, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.090932846069336 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 12.641721487045288s, objective value is 427142.5298796887.
# First solve objective is 427142.5397570299, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.717104196548462 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 12.595198154449463s, objective value is 427177.24598069716.
# First solve objective is 427177.2558736102, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.510652303695679 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.592476606369019s, objective value is 427019.44288670237.
# First solve objective is 427019.4527396768, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.871888160705566 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.70582914352417s, objective value is 426769.5488066037.
# First solve objective is 426769.55869332096, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 11.94087290763855 with 1 solve(s).
#
# For case pglib_opf_case2312_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case2312_goc in 10.456085920333862s, objective value is 427093.61167839676.
# First solve objective is 427093.62153731094, 0 violated cons.
# For method convex, solved pglib_opf_case2312_goc-reduced in 12.653024673461914 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 37.185423851013184s, objective value is 596348.1858443149.
# First solve objective is 596348.1858443023, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 18.873674869537354 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.52340865135193s, objective value is 592629.8202002657.
# First solve objective is 592629.820200762, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 20.80800223350525 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.431161880493164s, objective value is 591161.9597304619.
# First solve objective is 591161.9597308355, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 21.29305386543274 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 30.944931030273438s, objective value is 592519.4494380902.
# First solve objective is 592519.4494366902, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 19.06717610359192 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.709406852722168s, objective value is 592517.5063049104.
# First solve objective is 592517.5063049508, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 19.70864987373352 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 32.15078949928284s, objective value is 596318.773946299.
# First solve objective is 596318.7739465502, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 19.330281496047974 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.445037126541138s, objective value is 596496.2266359641.
# First solve objective is 596496.2266358199, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 20.701982975006104 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.922890424728394s, objective value is 590663.1684475561.
# First solve objective is 590663.1684480981, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 19.056191205978394 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 32.45868372917175s, objective value is 591202.9045410823.
# First solve objective is 591202.9045410701, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 19.12004041671753 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.536092519760132s, objective value is 595948.2702139263.
# First solve objective is 595948.2702129462, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 19.29654574394226 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.90972137451172s, objective value is 590491.5708634104.
# First solve objective is 590491.570863426, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 18.59813618659973 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.230684518814087s, objective value is 594202.1719408309.
# First solve objective is 594202.17194052, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 20.672221660614014 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.582590341567993s, objective value is 586443.5115021542.
# First solve objective is 586443.5115014163, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 20.7803795337677 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.4706130027771s, objective value is 595059.9078256384.
# First solve objective is 595059.9078264731, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 20.505047082901 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 32.23662805557251s, objective value is 597924.4540584949.
# First solve objective is 597924.4540585247, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 18.89821481704712 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 30.761424779891968s, objective value is 595434.115654237.
# First solve objective is 595434.115654329, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 18.909997940063477 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.673481225967407s, objective value is 594165.9387338976.
# First solve objective is 594165.9387339306, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 18.67795443534851 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.785730600357056s, objective value is 590174.1182222984.
# First solve objective is 590174.1182226026, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 21.162440299987793 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 32.48404288291931s, objective value is 589904.0254449192.
# First solve objective is 589904.025445301, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 20.451568365097046 with 1 solve(s).
#
# For case pglib_opf_case4601_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case4601_goc in 31.7731831073761s, objective value is 591547.1680561487.
# First solve objective is 591547.1680564863, 0 violated cons.
# For method convex, solved pglib_opf_case4601_goc-reduced in 21.767276763916016 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 48.895671367645264s, objective value is 1318997.6115405273.
# First solve objective is 1318997.611543442, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 53.08677577972412 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 50.8890221118927s, objective value is 1318997.611540431.
# First solve objective is 1318997.6115434421, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 47.970009088516235 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 49.024985551834106s, objective value is 1318997.6115406011.
# First solve objective is 1318997.6115434414, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 47.680541038513184 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 49.477380990982056s, objective value is 1318997.6115404842.
# First solve objective is 1318997.611543442, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 51.75749969482422 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 49.465224742889404s, objective value is 1318997.6115404835.
# First solve objective is 1318997.611543442, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 49.05853462219238 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 53.44708013534546s, objective value is 1318997.6115404665.
# First solve objective is 1318997.611543442, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 49.762126207351685 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 52.79124307632446s, objective value is 1318997.6115404416.
# First solve objective is 1318997.6115434421, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 53.34246754646301 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 52.18068337440491s, objective value is 1318997.6115405613.
# First solve objective is 1318997.6115434414, 0 violated cons.
# For method convex, solved pglib_opf_case10000_goc-reduced in 48.59742450714111 with 1 solve(s).
#
# For case pglib_opf_case10000_goc, init solve was feasible with info b'Algorithm terminated successfully at a locally optimal point, satisfying the convergence tolerances (can be specified by options).' and number 0. NOT CONTINUING.
# Solved original problem for pglib_opf_case10000_goc in 47.2377450466156s, objective value is 1318997.6115404544.

# %%
pd
# Out:
# array([0.45963642, 0.46164792, 0.46006271, ..., 0.45963643, 0.45963644,
#        0.45963643])
